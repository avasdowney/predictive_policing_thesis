# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

np.random.seed(1)

# %%
# read data
df = pd.read_csv('../data/Strategic_Subject_List_-_Historical.csv')
df.head()
# Out:
# /tmp/ipykernel_2205/2982276228.py:2: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/Strategic_Subject_List_-_Historical.csv')
#    SSL SCORE PREDICTOR RAT AGE AT LATEST ARREST  \
# 0        306                              20-30
# 1        352                              20-30
# 2        349                              20-30
# 3        344                              20-30
# 4        343                              20-30
#
#    PREDICTOR RAT VICTIM SHOOTING INCIDENTS  \
# 0                                        0
# 1                                        0
# 2                                        0
# 3                                        0
# 4                                        0
#
#    PREDICTOR RAT VICTIM BATTERY OR ASSAULT  \
# 0                                        0
# 1                                        1
# 2                                        0
# ...

# %%
df.drop(['MAJORITY DIST', 'DLST', 'IDOC RES CITY', 'IDOC RES STATE CODE', 'IDOC RES ZIP CODE', 'IDOC CPD DIST', 'TRAP FLAGS', 'SSL FLAGS'], axis=1, inplace = True)

# %%
# One-hot encode the data using pandas get_dummies
df = pd.get_dummies(df)
df.head()
# Out:
#    SSL SCORE  PREDICTOR RAT VICTIM SHOOTING INCIDENTS  \
# 0        306                                        0
# 1        352                                        0
# 2        349                                        0
# 3        344                                        0
# 4        343                                        0
#
#    PREDICTOR RAT VICTIM BATTERY OR ASSAULT  \
# 0                                        0
# 1                                        1
# 2                                        0
# 3                                        0
# 4                                        0
#
#    PREDICTOR RAT ARRESTS VIOLENT OFFENSES  PREDICTOR RAT GANG AFFILIATION  \
# 0                                       0                               0
# 1                                       0                               0
# 2                                       2                               0
# 3                                       3                               0
# ...
