# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

np.random.seed(1)

# %%
df = pd.read_csv('../data/all_census_aif360_data.csv')
df.head()
# Out:
#    SSL SCORE PREDICTOR RAT AGE AT LATEST ARREST  \
# 0          1                              20-30
# 1          1                              20-30
# 2          1                              20-30
# 3          0                              40-50
# 4          0                              40-50
#
#    PREDICTOR RAT VICTIM SHOOTING INCIDENTS  \
# 0                                        0
# 1                                        0
# 2                                        0
# 3                                        0
# 4                                        0
#
#    PREDICTOR RAT VICTIM BATTERY OR ASSAULT  \
# 0                                        0
# 1                                        0
# 2                                        0
# 3                                        0
# 4                                        0
#
#    PREDICTOR RAT ARRESTS VIOLENT OFFENSES  PREDICTOR RAT GANG AFFILIATION  \
# ...

# %%
my_dict = {0:'Low', 1:'High'}
df = df.replace({'SSL SCORE':my_dict})
df
# Out:
#        SSL SCORE PREDICTOR RAT AGE AT LATEST ARREST  \
# 0           High                              20-30
# 1           High                              20-30
# 2           High                              20-30
# 3            Low                              40-50
# 4            Low                              40-50
# ...          ...                                ...
# 223217      High                              30-40
# 223218       Low                              50-60
# 223219      High                              30-40
# 223220      High                              20-30
# 223221      High                              20-30
#
#         PREDICTOR RAT VICTIM SHOOTING INCIDENTS  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                             0
# ...

# %%
ax = sns.histplot(x = df['Education_Rate'], hue=df['SSL SCORE'], multiple="dodge", stat='density', shrink=0.8, bins=[10, 20, 30, 40, 50, 60, 70, 80, 90], common_norm=False)
ax.spines["top"].set_visible(False), ax.spines["right"].set_visible(False)
for p in ax.patches:
    ax.annotate('{:.3f}'.format(p.get_height()), (p.get_x()+.05, p.get_height()+0.001), rotation = 75)
ax.set_xlabel('Education Rate')
ax.set_title('Density of SSL Score by Education Rate', y=1.10)
ax.xaxis.set_major_locator(mtick.MultipleLocator(10))
ax.xaxis.set_major_formatter(mtick.PercentFormatter())

# %%
ax = sns.histplot(x = df['Employment_Rate'], hue=df['SSL SCORE'], multiple="dodge", stat='density', shrink=0.8, bins=[10, 20, 30, 40, 50, 60, 70, 80, 90], common_norm=False)
ax.spines["top"].set_visible(False), ax.spines["right"].set_visible(False)
for p in ax.patches:
    ax.annotate('{:.3f}'.format(p.get_height()), (p.get_x()+.05, p.get_height()+0.001), rotation = 75)
ax.set_xlabel('Employment Rate')
ax.set_title('Density of SSL Score by Employment Rate', y=1.10)
ax.xaxis.set_major_locator(mtick.MultipleLocator(10))
ax.xaxis.set_major_formatter(mtick.PercentFormatter())

# %%
ax = sns.histplot(x = df['Poverty_Rate'], hue=df['SSL SCORE'], multiple="dodge", stat='density', shrink=0.8, bins=[10, 20, 30, 40, 50, 60, 70, 80, 90], common_norm=False)
ax.spines["top"].set_visible(False), ax.spines["right"].set_visible(False)
for p in ax.patches:
    ax.annotate('{:.3f}'.format(p.get_height()), (p.get_x()+.05, p.get_height()+0.001), rotation = 75)
ax.set_xlabel('Poverty Rate')
ax.set_title('Density of SSL Score by Poverty Rate', y=1.10)
ax.xaxis.set_major_locator(mtick.MultipleLocator(10))
ax.xaxis.set_major_formatter(mtick.PercentFormatter())

# %%
ax = sns.histplot(x = df['Education_Rate'], hue=df['SSL SCORE'], multiple="dodge", shrink=0.8, bins=[10, 20, 30, 40, 50, 60, 70, 80, 90], common_norm=False)
ax.spines["top"].set_visible(False), ax.spines["right"].set_visible(False)
for p in ax.patches:
    ax.annotate('{:.3f}'.format(p.get_height()), (p.get_x()+.05, p.get_height()+.01), rotation = 75)
ax.set_xlabel('Education Rate')
ax.set_title('Count of SSL Score by Education Rate', y=1.10)
ax.xaxis.set_major_locator(mtick.MultipleLocator(10))
ax.xaxis.set_major_formatter(mtick.PercentFormatter())

# %%
ax = sns.histplot(x = df['Employment_Rate'], hue=df['SSL SCORE'], multiple="dodge", shrink=0.8, bins=[10, 20, 30, 40, 50, 60, 70, 80, 90], common_norm=False)
ax.spines["top"].set_visible(False), ax.spines["right"].set_visible(False)
for p in ax.patches:
    ax.annotate('{:.3f}'.format(p.get_height()), (p.get_x()+.05, p.get_height()+.01), rotation = 75)
ax.set_xlabel('Employment Rate')
ax.set_title('Count of SSL Score by Employment Rate', y=1.10)
ax.xaxis.set_major_locator(mtick.MultipleLocator(10))
ax.xaxis.set_major_formatter(mtick.PercentFormatter())

# %%
ax = sns.histplot(x = df['Poverty_Rate'], hue=df['SSL SCORE'], multiple="dodge", shrink=0.8, bins=[10, 20, 30, 40, 50, 60, 70, 80, 90], common_norm=False)
ax.spines["top"].set_visible(False), ax.spines["right"].set_visible(False)
for p in ax.patches:
    ax.annotate('{:.3f}'.format(p.get_height()), (p.get_x()+.05, p.get_height()+.01), rotation = 75)
ax.set_xlabel('Poverty Rate')
ax.set_title('Count of SSL Score by Poverty Rate', y=1.10)
ax.xaxis.set_major_locator(mtick.MultipleLocator(10))
ax.xaxis.set_major_formatter(mtick.PercentFormatter())

# %%
ax = sns.kdeplot(x ='Education_Rate', hue = "SSL SCORE", data = df)
ax.set_xlabel('Education Rate')
ax.set_title('Density of SSL Score by Education Rate', y=1.10)
ax.xaxis.set_major_locator(mtick.MultipleLocator(10))
ax.xaxis.set_major_formatter(mtick.PercentFormatter())
plt.show()

# %%
ax = sns.kdeplot(x ='Employment_Rate', hue = "SSL SCORE", data = df)
ax.set_xlabel('Employment Rate')
ax.set_title('Density of SSL Score by Employment Rate', y=1.10)
ax.xaxis.set_major_locator(mtick.MultipleLocator(10))
ax.xaxis.set_major_formatter(mtick.PercentFormatter())
plt.show()

# %%
ax = sns.kdeplot(x ='Poverty_Rate', hue = "SSL SCORE", data = df)
ax.set_xlabel('Poverty Rate')
ax.set_title('Density of SSL Score by Poverty Rate', y=1.10)
ax.xaxis.set_major_locator(mtick.MultipleLocator(10))
ax.xaxis.set_major_formatter(mtick.PercentFormatter())
plt.show()
